# %%
import h5py
import matplotlib.pyplot as plt
import numpy as np
import cv2
from scipy.spatial.transform import Rotation as Rot
import json
from mimicplay.scripts.aloha_process.simarUtils import *
import torchvision

# %%
# data = h5py.File("/coc/flash7/datasets/egoplay/oboov2_robot_apr16/oboov2_robot_apr16Mimicplay.hdf5", "r")
# data = h5py.File("/coc/flash7/datasets/egoplay/bowl_place_hand_mar1/robomimic/converted_episodes/plushiesMimicplay.hdf5", "r")
data = h5py.File("/coc/flash7/datasets/egoplay/oboo_aria_apr16/oboo_aria_apr16_rightMimicplay_with_type_label_copy.hdf5", "r")

# %%
nds(data)
# Out:
# dict with keys:  <KeysViewHDF5 ['data', 'mask']>
# data: dict with keys:  <KeysViewHDF5 ['demo_0', 'demo_1', 'demo_10', 'demo_100', 'demo_101', 'demo_102', 'demo_103', 'demo_104', 'demo_105', 'demo_106', 'demo_107', 'demo_108', 'demo_109', 'demo_11', 'demo_110', 'demo_111', 'demo_112', 'demo_113', 'demo_114', 'demo_115', 'demo_116', 'demo_117', 'demo_118', 'demo_119', 'demo_12', 'demo_120', 'demo_121', 'demo_122', 'demo_123', 'demo_124', 'demo_125', 'demo_126', 'demo_127', 'demo_128', 'demo_129', 'demo_13', 'demo_130', 'demo_131', 'demo_132', 'demo_133', 'demo_134', 'demo_135', 'demo_136', 'demo_137', 'demo_138', 'demo_139', 'demo_14', 'demo_140', 'demo_141', 'demo_142', 'demo_143', 'demo_144', 'demo_145', 'demo_146', 'demo_147', 'demo_148', 'demo_149', 'demo_15', 'demo_150', 'demo_151', 'demo_152', 'demo_153', 'demo_154', 'demo_155', 'demo_156', 'demo_157', 'demo_158', 'demo_159', 'demo_16', 'demo_160', 'demo_161', 'demo_162', 'demo_163', 'demo_164', 'demo_165', 'demo_166', 'demo_167', 'demo_168', 'demo_169', 'demo_17', 'demo_170', 'demo_171', 'demo_172', 'demo_173', 'demo_174', 'demo_175', 'demo_176', 'demo_177', 'demo_178', 'demo_179', 'demo_18', 'demo_180', 'demo_181', 'demo_182', 'demo_183', 'demo_184', 'demo_185', 'demo_186', 'demo_187', 'demo_188', 'demo_189', 'demo_19', 'demo_190', 'demo_191', 'demo_192', 'demo_193', 'demo_194', 'demo_195', 'demo_196', 'demo_197', 'demo_198', 'demo_199', 'demo_2', 'demo_20', 'demo_200', 'demo_201', 'demo_202', 'demo_203', 'demo_204', 'demo_205', 'demo_206', 'demo_207', 'demo_208', 'demo_209', 'demo_21', 'demo_210', 'demo_211', 'demo_212', 'demo_213', 'demo_214', 'demo_215', 'demo_216', 'demo_217', 'demo_218', 'demo_219', 'demo_22', 'demo_220', 'demo_221', 'demo_222', 'demo_223', 'demo_224', 'demo_225', 'demo_226', 'demo_227', 'demo_228', 'demo_229', 'demo_23', 'demo_230', 'demo_231', 'demo_232', 'demo_233', 'demo_234', 'demo_235', 'demo_236', 'demo_237', 'demo_238', 'demo_239', 'demo_24', 'demo_240', 'demo_241', 'demo_242', 'demo_243', 'demo_244', 'demo_245', 'demo_246', 'demo_247', 'demo_248', 'demo_249', 'demo_25', 'demo_250', 'demo_251', 'demo_252', 'demo_253', 'demo_254', 'demo_255', 'demo_256', 'demo_257', 'demo_258', 'demo_259', 'demo_26
dict with keys:  <KeysViewHDF5 ['actions', 'label', 'obs']>
# 		actions: (300, 30)
# 		label: (1,)
# 		obs: dict with keys:  <KeysViewHDF5 ['ee_pose', 'front_img_1']>
# 			ee_pose: (300, 3)
# 			front_img_1: (300, 480, 640, 3)
# 	demo_250: dict with keys:  <KeysViewHDF5 ['actions', 'label', 'obs']>
# 		actions: (300, 30)
# 		label: (1,)
# 		obs: dict with keys:  <KeysViewHDF5 ['ee_pose', 'front_img_1']>
# 			ee_pose: (300, 3)
# 			front_img_1: (300, 480, 640, 3)
# 	demo_251: dict with keys:  <KeysViewHDF5 ['actions', 'label', 'obs']>
# 		actions: (300, 30)
# 		label: (1,)
# 		obs: dict with keys:  <KeysViewHDF5 ['ee_pose', 'front_img_1']>
# 			ee_pose: (300, 3)
# 			front_img_1: (300, 480, 640, 3)
# 	demo_252: dict with keys:  <KeysViewHDF5 ['actions', 'label', 'obs']>
# 		actions: (300, 30)
# 		label: (1,)
# 		obs: dict with keys:  <KeysViewHDF5 ['ee_pose', 'front_img_1']>
# 			ee_pose: (300, 3)
# 			front_img_1: (300, 480, 640, 3)
# 	demo_253: dict with keys:  <KeysViewHDF5 ['actions', 'label', 'obs']>
# 		actions: (300, 30)
# 		label: (1,)
# 		obs: dict with keys:  <KeysViewHDF5 ['ee_pose', 'front_img_1']>
# 			ee_pose: (300, 3)
# 			front_img_1: (300, 480, 640, 3)
# 	demo_254: dict with keys:  <KeysViewHDF5 ['actions', 'label', 'obs']>
# 		actions: (289, 30)
# 		label: (1,)
# 		obs: dict with keys:  <KeysViewHDF5 ['ee_pose', 'front_img_1']>
# 			ee_pose: (289, 3)
# 			front_img_1: (289, 480, 640, 3)
# 	demo_255: dict with keys:  <KeysViewHDF5 ['actions', 'label', 'obs']>
# 		actions: (300, 30)
# 		label: (1,)
# 		obs: dict with keys:  <KeysViewHDF5 ['ee_pose', 'front_img_1']>
# 			ee_pose: (300, 3)
# 			front_img_1: (300, 480, 640, 3)
# 	demo_256: dict with keys:  <KeysViewHDF5 ['actions', 'label', 'obs']>
# 		actions: (300, 30)
# 		label: (1,)
# 		obs: dict with keys:  <KeysViewHDF5 ['ee_pose', 'front_img_1']>
# 			ee_pose: (300, 3)
# 			front_img_1: (300, 480, 640, 3)
# 	demo_257: dict with keys:  <KeysViewHDF5 ['actions', 'label', 'obs']>
# 		actions: (300, 30)
# 		label: (1,)
# 		obs: dict with keys:  <KeysViewHDF5 ['ee_pose', 'front_img_1']>
# 			ee_pose: (300, 3)
# 			front_img_1: (300, 480, 640, 3)
# 	demo_258: dict with keys:  <KeysViewHDF5 ['actions', 'label', 'obs']>
# 		actions: (300, 30)
# 		label: (1,)
# 		obs: dict with keys:  <KeysViewHDF5 ['ee_pose', 'front_img_1']>
# 			ee_pose: (300, 3)
# 			front_img_1: (300, 480, 640, 3)
# 	demo_259: dict with keys:  <KeysViewHDF5 ['actions', 'label', 'obs']>
# 		actions: (300, 30)
# 		label: (1,)
# 		obs: dict with keys:  <KeysViewHDF5 ['ee_pose', 'front_img_1']>
# 			ee_pose: (300, 3)
# 			front_img_1: (300, 480, 640, 3)
# 	demo_26: dict with keys:  <KeysViewHDF5 ['actions', 'label', 'obs']>
# 		actions: (300, 30)
# 		label: (1,)
# 		obs: dict with keys:  <KeysViewHDF5 ['ee_pose', 'front_img_1']>
# 			ee_pose: (300, 3)
# 			front_img_1: (300, 480, 640, 3)
# 	demo_260: dict with keys:  <KeysViewHDF5 ['actions', 'label', 'obs']>
# 		actions: (300, 30)
# 		label: (1,)
# 		obs: dict with keys:  <KeysViewHDF5 ['ee_pose', 'front_img_1']>
# 			ee_pose: (300, 3)
# 			front_img_1: (300, 480, 640, 3)
# 	demo_261: dict with keys:  <KeysViewHDF5 ['actions', 'label', 'obs']>
# 		actions: (300, 30)
# 		label: (1,)
# 		obs: dict with keys:  <KeysViewHDF5 ['ee_pose', 'front_img_1']>
# 			ee_pose: (300, 3)
# 			front_img_1: (300, 480, 640, 3)
# 	demo_262: dict with keys:  <KeysViewHDF5 ['actions', 'label', 'obs']>
# 		actions: (300, 30)
# 		label: (1,)
# 		obs: dict with keys:  <KeysViewHDF5 ['ee_pose', 'front_img_1']>
# 			ee_pose: (300, 3)
# 			front_img_1: (300, 480, 640, 3)
# 	demo_263: dict with keys:  <KeysViewHDF5 ['actions', 'label', 'obs']>
# 		actions: (300, 30)
# 		label: (1,)
# 		obs: dict with keys:  <KeysViewHDF5 ['ee_pose', 'front_img_1']>
# 			ee_pose: (300, 3)
# 			front_img_1: (300, 480, 640, 3)
# 	demo_264: dict with keys:  <KeysViewHDF5 ['actions', 'label', 'obs']>
# 		actions: (300, 30)
# 		label: (1,)
# 		obs: dict with keys:  <KeysViewHDF5 ['ee_pose', 'front_img_1']>
# 			ee_pose: (300, 3)
# 			front_img_1: (300, 480, 640, 3)
# 	demo_265: dict with keys:  <KeysViewHDF5 ['actions', 'label', 'obs']>
# 		actions: (300, 30)
# 		label: (1,)
# 		obs: dict with keys:  <KeysViewHDF5 ['ee_pose', 'front_img_1']>
# 			ee_pose: (300, 3)
# 			front_img_1: (300, 480, 640, 3)
# 	demo_266: dict with keys:  <KeysViewHDF5 ['actions', 'label', 'obs']>
# 		actions: (300, 30)
# 		label: (1,)
# 		obs: dict with keys:  <KeysViewHDF5 ['ee_pose', 'front_img_1']>
# 			ee_pose: (300, 3)
# 			front_img_1: (300, 480, 640, 3)
# 	demo_267: dict with keys:  <KeysViewHDF5 ['actions', 'label', 'obs']>
# 		actions: (300, 30)
# 		label: (1,)
# 		obs: dict with keys:  <KeysViewHDF5 ['ee_pose', 'front_img_1']>
# 			ee_pose: (300, 3)
# 			front_img_1: (300, 480, 640, 3)
# 	demo_268: dict with keys:  <KeysViewHDF5 ['actions', 'label', 'obs']>
# 		actions: (300, 30)
# 		label: (1,)
# 		obs: dict with keys:  <KeysViewHDF5 ['ee_pose', 'front_img_1']>
# 			ee_pose: (300, 3)
# 			front_img_1: (300, 480, 640, 3)
# 	demo_269: dict with keys:  <KeysViewHDF5 ['actions', 'label', 'obs']>
# 		actions: (300, 30)
# 		label: (1,)
# 		obs: dict with keys:  <KeysViewHDF5 ['ee_pose', 'front_img_1']>
# 			ee_pose: (300, 3)
# 			front_img_1: (300, 480, 640, 3)
# 	demo_27: dict with keys:  <KeysViewHDF5 ['actions', 'label', 'obs']>
# 		actions: (300, 30)
# 		label: (1,)
# 		obs: dict with keys:  <KeysViewHDF5 ['ee_pose', 'front_img_1']>
# 			ee_pose: (300, 3)
# 			front_img_1: (300, 480, 640, 3)
# 	demo_270: dict with keys:  <KeysViewHDF5 ['actions', 'label', 'obs']>
# 		actions: (300, 30)
# 		label: (1,)
# 		obs: dict with keys:  <KeysViewHDF5 ['ee_pose', 'front_img_1']>
# 			ee_pose: (300, 3)
# 			front_img_1: (300, 480, 640, 3)
# 	demo_271: dict with keys:  <KeysViewHDF5 ['actions', 'label', 'obs']>
# 		actions: (300, 30)
# 		label: (1,)
# 		obs: dict with keys:  <KeysViewHDF5 ['ee_pose', 'front_img_1']>
# 			ee_pose: (300, 3)
# 			front_img_1: (300, 480, 640, 3)
# 	demo_272: dict with keys:  <KeysViewHDF5 ['actions', 'label', 'obs']>
# 		actions: (300, 30)
# 		label: (1,)
# 		obs: dict with keys:  <KeysViewHDF5 ['ee_pose', 'front_img_1']>
# 			ee_pose: (300, 3)
# 			front_img_1: (300, 480, 640, 3)
# 	demo_273: dict with keys:  <KeysViewHDF5 ['actions', 'label', 'obs']>
# 		actions: (300, 30)
# 		label: (1,)
# 		obs: dict with keys:  <KeysViewHDF5 ['ee_pose', 'front_img_1']>
# 			ee_pose: (300, 3)
# 			front_img_1: (300, 480, 640, 3)
# 	demo_274: dict with keys:  <KeysViewHDF5 ['actions', 'label', 'obs']>
# 		actions: (300, 30)
# 		label: (1,)
# 		obs: dict with keys:  <KeysViewHDF5 ['ee_pose', 'front_img_1']>
# ...
# 	demo_36: dict with keys:  <KeysViewHDF5 ['actions', 'label', 'obs']>
# 		actions: (300, 30)
# 		label: (1,)
# 		obs: dict with keys:  <KeysViewHDF5 ['ee_pose', 'front_img_1']>
# 			ee_pose: (300, 3)
# 			front_img_1: (300, 480, 640, 3)
# 	demo_37: dict with keys:  <KeysViewHDF5 ['actions', 'label', 'obs']>
# 		actions: (300, 30)
# 		label: (1,)
# 		obs: dict with keys:  <KeysViewHDF5 ['ee_pose', 'front_img_1']>
# 			ee_pose: (300, 3)
# 			front_img_1: (300, 480, 640, 3)
# 	demo_38: dict with keys:  <KeysViewHDF5 ['actions', 'label', 'obs']>
# 		actions: (300, 30)
# 		label: (1,)
# 		obs: dict with keys:  <KeysViewHDF5 ['ee_pose', 'front_img_1']>
# 			ee_pose: (300, 3)
# 			front_img_1: (300, 480, 640, 3)
# 	demo_39: dict with keys:  <KeysViewHDF5 ['actions', 'label', 'obs']>
# 		actions: (300, 30)
# 		label: (1,)
# 		obs: dict with keys:  <KeysViewHDF5 ['ee_pose', 'front_img_1']>
# 			ee_pose: (300, 3)
# 			front_img_1: (300, 480, 640, 3)
# 	demo_4: dict with keys:  <KeysViewHDF5 ['actions', 'label', 'obs']>
# 		actions: (300, 30)
# 		label: (1,)
# 		obs: dict with keys:  <KeysViewHDF5 ['ee_pose', 'front_img_1']>
# 			ee_pose: (300, 3)
# 			front_img_1: (300, 480, 640, 3)
# 	demo_40: dict with keys:  <KeysViewHDF5 ['actions', 'label', 'obs']>
# 		actions: (300, 30)
# 		label: (1,)
# 		obs: dict with keys:  <KeysViewHDF5 ['ee_pose', 'front_img_1']>
# 			ee_pose: (300, 3)
# 			front_img_1: (300, 480, 640, 3)
# 	demo_41: dict with keys:  <KeysViewHDF5 ['actions', 'label', 'obs']>
# 		actions: (300, 30)
# 		label: (1,)
# 		obs: dict with keys:  <KeysViewHDF5 ['ee_pose', 'front_img_1']>
# 			ee_pose: (300, 3)
# 			front_img_1: (300, 480, 640, 3)
# 	demo_42: dict with keys:  <KeysViewHDF5 ['actions', 'label', 'obs']>
# 		actions: (300, 30)
# 		label: (1,)
# 		obs: dict with keys:  <KeysViewHDF5 ['ee_pose', 'front_img_1']>
# 			ee_pose: (300, 3)
# 			front_img_1: (300, 480, 640, 3)
# 	demo_43: dict with keys:  <KeysViewHDF5 ['actions', 'label', 'obs']>
# 		actions: (300, 30)
# 		label: (1,)
# 		obs: dict with keys:  <KeysViewHDF5 ['ee_pose', 'front_img_1']>
# 			ee_pose: (300, 3)
# 			front_img_1: (300, 480, 640, 3)
# 	demo_44: dict with keys:  <KeysViewHDF5 ['actions', 'label', 'obs']>
# 		actions: (300, 30)
# 		label: (1,)
# 		obs: dict with keys:  <KeysViewHDF5 ['ee_pose', 'front_img_1']>
# 			ee_pose: (300, 3)
# 			front_img_1: (300, 480, 640, 3)
# 	demo_45: dict with keys:  <KeysViewHDF5 ['actions', 'label', 'obs']>
# 		actions: (300, 30)
# 		label: (1,)
# 		obs: dict with keys:  <KeysViewHDF5 ['ee_pose', 'front_img_1']>
# 			ee_pose: (300, 3)
# 			front_img_1: (300, 480, 640, 3)
# 	demo_46: dict with keys:  <KeysViewHDF5 ['actions', 'label', 'obs']>
# 		actions: (300, 30)
# 		label: (1,)
# 		obs: dict with keys:  <KeysViewHDF5 ['ee_pose', 'front_img_1']>
# 			ee_pose: (300, 3)
# 			front_img_1: (300, 480, 640, 3)
# 	demo_47: dict with keys:  <KeysViewHDF5 ['actions', 'label', 'obs']>
# 		actions: (300, 30)
# 		label: (1,)
# 		obs: dict with keys:  <KeysViewHDF5 ['ee_pose', 'front_img_1']>
# 			ee_pose: (300, 3)
# 			front_img_1: (300, 480, 640, 3)
# 	demo_48: dict with keys:  <KeysViewHDF5 ['actions', 'label', 'obs']>
# 		actions: (300, 30)
# 		label: (1,)
# 		obs: dict with keys:  <KeysViewHDF5 ['ee_pose', 'front_img_1']>
# 			ee_pose: (300, 3)
# 			front_img_1: (300, 480, 640, 3)
# 	demo_49: dict with keys:  <KeysViewHDF5 ['actions', 'label', 'obs']>
# 		actions: (300, 30)
# 		label: (1,)
# 		obs: dict with keys:  <KeysViewHDF5 ['ee_pose', 'front_img_1']>
# 			ee_pose: (300, 3)
# 			front_img_1: (300, 480, 640, 3)
# 	demo_5: dict with keys:  <KeysViewHDF5 ['actions', 'label', 'obs']>
# 		actions: (300, 30)
# 		label: (1,)
# 		obs: dict with keys:  <KeysViewHDF5 ['ee_pose', 'front_img_1']>
# 			ee_pose: (300, 3)
# 			front_img_1: (300, 480, 640, 3)
# 	demo_50: dict with keys:  <KeysViewHDF5 ['actions', 'label', 'obs']>
# 		actions: (300, 30)
# 		label: (1,)
# 		obs: dict with keys:  <KeysViewHDF5 ['ee_pose', 'front_img_1']>
# 			ee_pose: (300, 3)
# 			front_img_1: (300, 480, 640, 3)
# 	demo_51: dict with keys:  <KeysViewHDF5 ['actions', 'label', 'obs']>
# 		actions: (300, 30)
# 		label: (1,)
# 		obs: dict with keys:  <KeysViewHDF5 ['ee_pose', 'front_img_1']>
# 			ee_pose: (300, 3)
# 			front_img_1: (300, 480, 640, 3)
# 	demo_52: dict with keys:  <KeysViewHDF5 ['actions', 'label', 'obs']>
# 		actions: (300, 30)
# 		label: (1,)
# 		obs: dict with keys:  <KeysViewHDF5 ['ee_pose', 'front_img_1']>
# 			ee_pose: (300, 3)
# 			front_img_1: (300, 480, 640, 3)
# 	demo_53: dict with keys:  <KeysViewHDF5 ['actions', 'label', 'obs']>
# 		actions: (300, 30)
# 		label: (1,)
# 		obs: dict with keys:  <KeysViewHDF5 ['ee_pose', 'front_img_1']>
# 			ee_pose: (300, 3)
# 			front_img_1: (300, 480, 640, 3)
# 	demo_54: dict with keys:  <KeysViewHDF5 ['actions', 'label', 'obs']>
# 		actions: (300, 30)
# 		label: (1,)
# 		obs: dict with keys:  <KeysViewHDF5 ['ee_pose', 'front_img_1']>
# 			ee_pose: (300, 3)
# 			front_img_1: (300, 480, 640, 3)
# 	demo_55: dict with keys:  <KeysViewHDF5 ['actions', 'label', 'obs']>
# 		actions: (300, 30)
# 		label: (1,)
# 		obs: dict with keys:  <KeysViewHDF5 ['ee_pose', 'front_img_1']>
# 			ee_pose: (300, 3)
# 			front_img_1: (300, 480, 640, 3)
# 	demo_56: dict with keys:  <KeysViewHDF5 ['actions', 'label', 'obs']>
# 		actions: (300, 30)
# 		label: (1,)
# 		obs: dict with keys:  <KeysViewHDF5 ['ee_pose', 'front_img_1']>
# 			ee_pose: (300, 3)
# 			front_img_1: (300, 480, 640, 3)
# 	demo_57: dict with keys:  <KeysViewHDF5 ['actions', 'label', 'obs']>
# 		actions: (300, 30)
# 		label: (1,)
# 		obs: dict with keys:  <KeysViewHDF5 ['ee_pose', 'front_img_1']>
# 			ee_pose: (300, 3)
# 			front_img_1: (300, 480, 640, 3)
# 	demo_58: dict with keys:  <KeysViewHDF5 ['actions', 'label', 'obs']>
# 		actions: (229, 30)
# 		label: (1,)
# 		obs: dict with keys:  <KeysViewHDF5 ['ee_pose', 'front_img_1']>
# 			ee_pose: (229, 3)
# 			front_img_1: (229, 480, 640, 3)
# 	demo_59: dict with keys:  <KeysViewHDF5 ['actions', 'label', 'obs']>
# 		actions: (300, 30)
# 		label: (1,)
# 		obs: dict with keys:  <KeysViewHDF5 ['ee_pose', 'front_img_1']>
# 			ee_pose: (300, 3)
# 			front_img_1: (300, 480, 640, 3)
# 	demo_6: dict with keys:  <KeysViewHDF5 ['actions', 'label', 'obs']>
# 		actions: (300, 30)
# 		label: (1,)
# 		obs: dict with keys:  <KeysViewHDF5 ['ee_pose', 'front_img_1']>
# 			ee_pose: (300, 3)
# 			front_img_1: (300, 480, 640, 3)
# 	demo_60: dict with keys:  <KeysViewHDF5 ['actions', 'label', 'obs']>
# 		actions: (300, 30)
# 		label: (1,)
# 		obs: dict with keys:  <KeysViewHDF5 ['ee_pose', 'front_img_1']>
# 			ee_pose: (300, 3)
# 			front_img_1: (300, 480, 640, 3)
# 	demo_61: dict with keys:  <KeysViewHDF5 ['actions', 'label', 'obs']>
# 		actions: (300, 30)
# 		label: (1,)
# 		obs: dict with keys:  <KeysViewHDF5 ['ee_pose', 'front_img_1']>
# 			ee_pose: (300, 3)
# 			front_img_1: (300, 480, 640, 3)
# 	demo_62: dict with keys:  <KeysViewHDF5 ['actions', 'label', 'obs']>
# 		actions: (300, 30)
# 		label: (1,)
# 		obs: dict with keys:  <KeysViewHDF5 ['ee_pose', 'front_img_1']>
# 			ee_pose: (300, 3)
# 			front_img_1: (300, 480, 640, 3)
# 	demo_63: dict with keys:  <KeysViewHDF5 ['actions', 'label', 'obs']>
# 		actions: (300, 30)
# 		label: (1,)
# 		obs: dict with keys:  <KeysViewHDF5 ['ee_pose', 'front_img_1']>
# 			ee_pose: (300, 3)
# 			front_img_1: (300, 480, 640, 3)
# 	demo_64: dict with keys:  <KeysViewHDF5 ['actions', 'label', 'obs']>
# 		actions: (300, 30)
# 		label: (1,)
# 		obs: dict with keys:  <KeysViewHDF5 ['ee_pose', 'front_img_1']>
# 			ee_pose: (300, 3)
# 			front_img_1: (300, 480, 640, 3)
# 	demo_65: dict with keys:  <KeysViewHDF5 ['actions', 'label', 'obs']>
# 		actions: (300, 30)
# 		label: (1,)
# 		obs: dict with keys:  <KeysViewHDF5 ['ee_pose', 'front_img_1']>
# 			ee_pose: (300, 3)
# 			front_img_1: (300, 480, 640, 3)
# 	demo_66: dict with keys:  <KeysViewHDF5 ['actions', 'label', 'obs']>
# 		actions: (300, 30)
# 		label: (1,)
# 		obs: dict with keys:  <KeysViewHDF5 ['ee_pose', 'front_img_1']>
# 			ee_pose: (300, 3)
# 			front_img_1: (300, 480, 640, 3)
# 	demo_67: dict with keys:  <KeysViewHDF5 ['actions', 'label', 'obs']>
# 		actions: (300, 30)
# 		label: (1,)
# 		obs: dict with keys:  <KeysViewHDF5 ['ee_pose', 'front_img_1']>
# 			ee_pose: (300, 3)
# 			front_img_1: (300, 480, 640, 3)
# 	demo_68: dict with keys:  <KeysViewHDF5 ['actions', 'label', 'obs']>
# 		actions: (300, 30)
# 		label: (1,)
# 		obs: dict with keys:  <KeysViewHDF5 ['ee_pose', 'front_img_1']>
# 			ee_pose: (300, 3)
# 			front_img_1: (300, 480, 640, 3)
# 	demo_69: dict with keys:  <KeysViewHDF5 ['actions', 'label', 'obs']>
# 		actions: (300, 30)
# 		label: (1,)
# 		obs: dict with keys:  <KeysViewHDF5 ['ee_pose', 'front_img_1']>
# 			ee_pose: (300, 3)
# 			front_img_1: (300, 480, 640, 3)
# 	demo_7: dict with keys:  <KeysViewHDF5 ['actions', 'label', 'obs']>
# 		actions: (300, 30)
# 		label: (1,)
# 		obs: dict with keys:  <KeysViewHDF5 ['ee_pose', 'front_img_1']>
# 			ee_pose: (300, 3)
# 			front_img_1: (300, 480, 640, 3)
# 	demo_70: dict with keys:  <KeysViewHDF5 ['actions', 'label', 'obs']>
# 		actions: (300, 30)
# 		label: (1,)
# 		obs: dict with keys:  <KeysViewHDF5 ['ee_pose', 'front_img_1']>
# 			ee_pose: (300, 3)
# 			front_img_1: (300, 480, 640, 3)
# 	demo_71: dict with keys:  <KeysViewHDF5 ['actions', 'label', 'obs']>
# 		actions: (300, 30)
# 		label: (1,)
# 		obs: dict with keys:  <KeysViewHDF5 ['ee_pose', 'front_img_1']>
# 			ee_pose: (300, 3)
# 			front_img_1: (300, 480, 640, 3)
# 	demo_72: dict with keys:  <KeysViewHDF5 ['actions', 'label', 'obs']>
# 		actions: (300, 30)
# 		label: (1,)
# 		obs: dict with keys:  <KeysViewHDF5 ['ee_pose', 'front_img_1']>
# 			ee_pose: (300, 3)
# 			front_img_1: (300, 480, 640, 3)
# 	demo_73: dict with keys:  <KeysViewHDF5 ['actions', 'label', 'obs']>
# 		actions: (300, 30)
# 		label: (1,)
# 		obs: dict with keys:  <KeysViewHDF5 ['ee_pose', 'front_img_1']>
# 			ee_pose: (300, 3)
# 			front_img_1: (300, 480, 640, 3)
# 	demo_74: dict with keys:  <KeysViewHDF5 ['actions', 'label', 'obs']>
# 		actions: (300, 30)
# 		label: (1,)
# 		obs: dict with keys:  <KeysViewHDF5 ['ee_pose', 'front_img_1']>
# 			ee_pose: (300, 3)
# 			front_img_1: (300, 480, 640, 3)
# 	demo_75: dict with keys:  <KeysViewHDF5 ['actions', 'label', 'obs']>
# 		actions: (300, 30)
# 		label: (1,)
# 		obs: dict with keys:  <KeysViewHDF5 ['ee_pose', 'front_img_1']>
# 			ee_pose: (300, 3)
# 			front_img_1: (300, 480, 640, 3)
# 	demo_76: dict with keys:  <KeysViewHDF5 ['actions', 'label', 'obs']>
# 		actions: (300, 30)
# 		label: (1,)
# 		obs: dict with keys:  <KeysViewHDF5 ['ee_pose', 'front_img_1']>
# 			ee_pose: (300, 3)
# 			front_img_1: (300, 480, 640, 3)
# 	demo_77: dict with keys:  <KeysViewHDF5 ['actions', 'label', 'obs']>
# 		actions: (300, 30)
# 		label: (1,)
# 		obs: dict with keys:  <KeysViewHDF5 ['ee_pose', 'front_img_1']>
# 			ee_pose: (300, 3)
# 			front_img_1: (300, 480, 640, 3)
# 	demo_78: dict with keys:  <KeysViewHDF5 ['actions', 'label', 'obs']>
# 		actions: (300, 30)
# 		label: (1,)
# 		obs: dict with keys:  <KeysViewHDF5 ['ee_pose', 'front_img_1']>
# 			ee_pose: (300, 3)
# 			front_img_1: (300, 480, 640, 3)
# 	demo_79: dict with keys:  <KeysViewHDF5 ['actions', 'label', 'obs']>
# 		actions: (300, 30)
# 		label: (1,)
# 		obs: dict with keys:  <KeysViewHDF5 ['ee_pose', 'front_img_1']>
# 			ee_pose: (300, 3)
# 			front_img_1: (300, 480, 640, 3)
# 	demo_8: dict with keys:  <KeysViewHDF5 ['actions', 'label', 'obs']>
# 		actions: (300, 30)
# 		label: (1,)
# 		obs: dict with keys:  <KeysViewHDF5 ['ee_pose', 'front_img_1']>
# 			ee_pose: (300, 3)
# 			front_img_1: (300, 480, 640, 3)
# 	demo_80: dict with keys:  <KeysViewHDF5 ['actions', 'label', 'obs']>
# 		actions: (300, 30)
# 		label: (1,)
# 		obs: dict with keys:  <KeysViewHDF5 ['ee_pose', 'front_img_1']>
# 			ee_pose: (300, 3)
# 			front_img_1: (300, 480, 640, 3)
# 	demo_81: dict with keys:  <KeysViewHDF5 ['actions', 'label', 'obs']>
# 		actions: (300, 30)
# 		label: (1,)
# 		obs: dict with keys:  <KeysViewHDF5 ['ee_pose', 'front_img_1']>
# 			ee_pose: (300, 3)
# 			front_img_1: (300, 480, 640, 3)
# 	demo_82: dict with keys:  <KeysViewHDF5 ['actions', 'label', 'obs']>
# 		actions: (300, 30)
# 		label: (1,)
# 		obs: dict with keys:  <KeysViewHDF5 ['ee_pose', 'front_img_1']>
# 			ee_pose: (300, 3)
# 			front_img_1: (300, 480, 640, 3)
# 	demo_83: dict with keys:  <KeysViewHDF5 ['actions', 'label', 'obs']>
# 		actions: (300, 30)
# 		label: (1,)
# 		obs: dict with keys:  <KeysViewHDF5 ['ee_pose', 'front_img_1']>
# 			ee_pose: (300, 3)
# 			front_img_1: (300, 480, 640, 3)
# 	demo_84: dict with keys:  <KeysViewHDF5 ['actions', 'label', 'obs']>
# 		actions: (300, 30)
# 		label: (1,)
# 		obs: dict with keys:  <KeysViewHDF5 ['ee_pose', 'front_img_1']>
# 			ee_pose: (300, 3)
# 			front_img_1: (300, 480, 640, 3)
# 	demo_85: dict with keys:  <KeysViewHDF5 ['actions', 'label', 'obs']>
# 		actions: (300, 30)
# 		label: (1,)
# 		obs: dict with keys:  <KeysViewHDF5 ['ee_pose', 'front_img_1']>
# 			ee_pose: (300, 3)
# 			front_img_1: (300, 480, 640, 3)
# 	demo_86: dict with keys:  <KeysViewHDF5 ['actions', 'label', 'obs']>
# 		actions: (300, 30)
# 		label: (1,)
# 		obs: dict with keys:  <KeysViewHDF5 ['ee_pose', 'front_img_1']>
# 			ee_pose: (300, 3)
# 			front_img_1: (300, 480, 640, 3)
# 	demo_87: dict with keys:  <KeysViewHDF5 ['actions', 'label', 'obs']>
# 		actions: (300, 30)
# 		label: (1,)
# 		obs: dict with keys:  <KeysViewHDF5 ['ee_pose', 'front_img_1']>
# 			ee_pose: (300, 3)
# 			front_img_1: (300, 480, 640, 3)
# 	demo_88: dict with keys:  <KeysViewHDF5 ['actions', 'label', 'obs']>
# 		actions: (300, 30)
# 		label: (1,)
# 		obs: dict with keys:  <KeysViewHDF5 ['ee_pose', 'front_img_1']>
# 			ee_pose: (300, 3)
# 			front_img_1: (300, 480, 640, 3)
# 	demo_89: dict with keys:  <KeysViewHDF5 ['actions', 'label', 'obs']>
# 		actions: (218, 30)
# 		label: (1,)
# 		obs: dict with keys:  <KeysViewHDF5 ['ee_pose', 'front_img_1']>
# 			ee_pose: (218, 3)
# 			front_img_1: (218, 480, 640, 3)
# 	demo_9: dict with keys:  <KeysViewHDF5 ['actions', 'label', 'obs']>
# 		actions: (300, 30)
# 		label: (1,)
# 		obs: dict with keys:  <KeysViewHDF5 ['ee_pose', 'front_img_1']>
# 			ee_pose: (300, 3)
# 			front_img_1: (300, 480, 640, 3)
# 	demo_90: dict with keys:  <KeysViewHDF5 ['actions', 'label', 'obs']>
# 		actions: (300, 30)
# 		label: (1,)
# 		obs: dict with keys:  <KeysViewHDF5 ['ee_pose', 'front_img_1']>
# 			ee_pose: (300, 3)
# 			front_img_1: (300, 480, 640, 3)
# 	demo_91: dict with keys:  <KeysViewHDF5 ['actions', 'label', 'obs']>
# 		actions: (300, 30)
# 		label: (1,)
# 		obs: dict with keys:  <KeysViewHDF5 ['ee_pose', 'front_img_1']>
# 			ee_pose: (300, 3)
# 			front_img_1: (300, 480, 640, 3)
# 	demo_92: dict with keys:  <KeysViewHDF5 ['actions', 'label', 'obs']>
# 		actions: (300, 30)
# 		label: (1,)
# 		obs: dict with keys:  <KeysViewHDF5 ['ee_pose', 'front_img_1']>
# 			ee_pose: (300, 3)
# 			front_img_1: (300, 480, 640, 3)
# 	demo_93: dict with keys:  <KeysViewHDF5 ['actions', 'label', 'obs']>
# 		actions: (300, 30)
# 		label: (1,)
# 		obs: dict with keys:  <KeysViewHDF5 ['ee_pose', 'front_img_1']>
# 			ee_pose: (300, 3)
# 			front_img_1: (300, 480, 640, 3)
# 	demo_94: dict with keys:  <KeysViewHDF5 ['actions', 'label', 'obs']>
# 		actions: (300, 30)
# 		label: (1,)
# 		obs: dict with keys:  <KeysViewHDF5 ['ee_pose', 'front_img_1']>
# 			ee_pose: (300, 3)
# 			front_img_1: (300, 480, 640, 3)
# 	demo_95: dict with keys:  <KeysViewHDF5 ['actions', 'label', 'obs']>
# 		actions: (300, 30)
# 		label: (1,)
# 		obs: dict with keys:  <KeysViewHDF5 ['ee_pose', 'front_img_1']>
# 			ee_pose: (300, 3)
# 			front_img_1: (300, 480, 640, 3)
# 	demo_96: dict with keys:  <KeysViewHDF5 ['actions', 'label', 'obs']>
# 		actions: (300, 30)
# 		label: (1,)
# 		obs: dict with keys:  <KeysViewHDF5 ['ee_pose', 'front_img_1']>
# 			ee_pose: (300, 3)
# 			front_img_1: (300, 480, 640, 3)
# 	demo_97: dict with keys:  <KeysViewHDF5 ['actions', 'label', 'obs']>
# 		actions: (300, 30)
# 		label: (1,)
# 		obs: dict with keys:  <KeysViewHDF5 ['ee_pose', 'front_img_1']>
# 			ee_pose: (300, 3)
# 			front_img_1: (300, 480, 640, 3)
# 	demo_98: dict with keys:  <KeysViewHDF5 ['actions', 'label', 'obs']>
# 		actions: (300, 30)
# 		label: (1,)
# 		obs: dict with keys:  <KeysViewHDF5 ['ee_pose', 'front_img_1']>
# 			ee_pose: (300, 3)
# 			front_img_1: (300, 480, 640, 3)
# 	demo_99: dict with keys:  <KeysViewHDF5 ['actions', 'label', 'obs']>
# 		actions: (300, 30)
# 		label: (1,)
# 		obs: dict with keys:  <KeysViewHDF5 ['ee_pose', 'front_img_1']>
# 			ee_pose: (300, 3)
# 			front_img_1: (300, 480, 640, 3)
# mask: dict with keys:  <KeysViewHDF5 ['train', 'valid']>
# 	train: (227,)
# 	valid: (57,)

# %%
plt.imshow(data["data/demo_1/obs/front_img_1"][0])

# %%
import os
import random
output_path = "/nethome/skareer6/flash9/Projects/EgoPlay/diffusers/data/hand_images"
# Get the list of demo names from the HDF5 data object
demo_names = list(data.keys())

# Create the output folder if it doesn't exist
os.makedirs(output_path, exist_ok=True)

# Randomly sample one image per demo and save it in the output folder
for i in range(200):
    demo_group = data[f"data/demo_{i+1}"]
    rand_frame = random.randint(0, len(demo_group["obs/front_img_1"]) - 1)
    img = demo_group["obs/front_img_1"][rand_frame]
    # img = img[:, :, [2, 1, 0]]

    plt.imsave(f"{output_path}/demo_{i}.png", img.astype(np.uint8))

# %% [markdown]
# ## Raw Aloha

# %%
data = h5py.File("/coc/flash7/datasets/egoplay/diffusion/episode_0.hdf5", "r")
nds(data)
# Out:
# dict with keys:  <KeysViewHDF5 ['action', 'observations']>
# action: (5000, 14)
# observations: dict with keys:  <KeysViewHDF5 ['effort', 'images', 'qpos', 'qvel']>
# 	effort: (5000, 14)
# 	images: dict with keys:  <KeysViewHDF5 ['cam_high', 'cam_right_wrist', 'cam_right_wrist_raw_depth']>
# 		cam_high: (5000, 480, 640, 3)
# 		cam_right_wrist: (5000, 480, 640, 3)
# 		cam_right_wrist_raw_depth: (5000, 480, 640)
# 	qpos: (5000, 14)
# 	qvel: (5000, 14)

# %%
import os
import random
output_path = "/nethome/skareer6/flash9/Projects/EgoPlay/diffusers/data/robo_images_crop"
# Get the list of demo names from the HDF5 data object
# demo_names = list(data.keys())

# Create the output folder if it doesn't exist
os.makedirs(output_path, exist_ok=True)

# Randomly sample one image per demo and save it in the output folder
for i in range(0, 5000, 50):
    img = data["observations/images/cam_high"][i]

    plt.imsave(os.path.join(output_path, f"demo_{i}.png"), img.astype(np.uint8))
